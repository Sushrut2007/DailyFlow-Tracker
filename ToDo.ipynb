# %% [markdown]
# # 🧭 Flow Mapper — Developer Roadmap (VS Code Version)
#
# Track your daily tasks, analyze patterns, and visualize your flow — all from a lightweight, local Python project.
#
# ---
#
# ## 🗂 Folder Structure
#
# ```
# flow-mapper/
# │
# ├── src/
# │   └── logger.py           # Core logic: logging and reading
# │   └── analyzer.py         # Time grouping and summary
# │   └── visualizer.py       # Matplotlib plots
# │
# ├── data/
# │   └── activity_log.csv    # Logged entries
# │
# ├── notebooks/
# │   └── exploration.ipynb   # Optional: for testing ideas
# │
# ├── images/                 # Exported charts (if any)
# │
# ├── .gitignore
# ├── README.md
# ├── TODO.md
# └── main.py                 # Entry point script
# ```
#
# ---
#
# ## ✅ Step-by-Step Dev Plan
#
# ### 🔧 Phase 1: Project Setup
#
# - [x] Create project folder `flow-mapper/`
# - [x] Set up `/src`, `/data`, `/images`, `/notebooks`
# - [x] Initialize Git
#   ```bash
#   git init
#   ```
#
# - [x] Create `.gitignore`:
#   ```
#   __pycache__/
#   .ipynb_checkpoints/
#   *.csv
#   *.png
#   *.log
#   ```
#
# - [x] First commit:
#   ```bash
#   git add .
#   git commit -m "Initial project structure"
#   ```
#
# ---
#
# ## 🌐 Phase 2: GitHub Sync
#
# - [x] Create GitHub repo: `flow-mapper`
# - [x] Connect remote:
#   ```bash
#   git remote add origin https://github.com/YOUR_USERNAME/flow-mapper.git
#   git branch -M main
#   git push -u origin main
#   ```
#
# ---
#
# ## 🧠 Phase 3: Core Features
#
# ### 📍 Logger (`logger.py`)
# - [ ] `log_activity()` — Input: task name, start time, end time
# - [ ] Append to `activity_log.csv`
# - [ ] Optionally add tag (focus/break)
#
# ### 📍 Analyzer (`analyzer.py`)
# - [ ] `load_data()` — Read and clean CSV
# - [ ] `summarize_by_task()` — Total time per task
# - [ ] `top_tasks()`, `most_active_hour()`
#
# ### 📍 Visualizer (`visualizer.py`)
# - [ ] Pie chart: Task time share
# - [ ] Bar chart: Hourly breakdown
# - [ ] Save plots to `/images/`
#
# ### 📍 Main script (`main.py`)
# - [ ] CLI or menu to:
#   - Add activity
#   - Generate report
#   - Show visual charts
#
# ---
#
# ## 🔁 Phase 4: Git Workflow (Clean Commits)
#
# - [ ] Create new feature branches:
#   ```bash
#   git checkout -b feature/logger
#   ```
#
# - [ ] Commit regularly:
#   ```bash
#   git add .
#   git commit -m "Add log function"
#   git push origin feature/logger
#   ```
#
# - [ ] Merge to `main` via GitHub PR
#   - Go to Pull Requests → New Pull Request
#   - Review → Merge → Delete branch
#
# ---
#
# ## 📊 Phase 5: Test & Polish
#
# - [ ] Handle edge cases (empty data, invalid time)
# - [ ] Add error logging if needed
# - [ ] Refactor for clarity
# - [ ] Optional: notebook demo version
#
# ---
#
# ## 🔮 Phase 6: Possible Extensions
#
# - [ ] Weekly trend analyzer
# - [ ] Tag-based filtering (focus, break, distraction)
# - [ ] Export report (PDF/HTML)
# - [ ] Basic ML (detect distracted vs focused sessions)
#
# ---
#
# ## 🧰 Git & GitHub Tips
#
# - 🔁 Always `pull` before pushing:
#   ```bash
#   git pull origin main
#   ```
#
# - ✏️ Clear commit messages help:
#   ```
#   "Fix duration bug in analyzer"
#   "Add pie chart plot"
#   ```
#
# - 🔄 Reset repo safely if messed up:
#   ```bash
#   git reset --hard origin/main
#   ```
#
# ---
#
# ## 📌 Legend
#
# - [ ] Task pending
# - [x] Done
# - ➕ Optional
#
# ---
#
# > This `TODO.md` evolves with your project. Keep updating as you grow. Let your roadmap breathe 🚀
